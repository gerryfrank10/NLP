# %%
import spacy
spacy.__version__
# Out:
# '3.8.7'

# %%
# !pip install IPython==7.34.0
# Out:
# Collecting IPython==7.34.0
#   Downloading ipython-7.34.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: setuptools>=18.5 in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (78.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (0.19.2)
# Requirement already satisfied: decorator in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (5.1.1)
# Collecting pickleshare (from IPython==7.34.0)
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: traitlets>=4.2 in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (5.14.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (3.0.43)
# Requirement already satisfied: pygments in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (2.19.1)
# Collecting backcall (from IPython==7.34.0)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib-inline in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (0.1.6)
# Requirement already satisfied: colorama in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from IPython==7.34.0) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython==7.34.0) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\gerry\anaconda3\envs\nlp\lib\site-packages (from jedi>=0.16->IPython==7.34.0) (0.8.4)
# Downloading ipython-7.34.0-py3-none-any.whl (793 kB)
#    ---------------------------------------- 0.0/793.8 kB ? eta -:--:--
#    --------------------------------------- 793.8/793.8 kB 11.3 MB/s eta 0:00:00
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare, backcall, IPython
#
#    -------------------------- ------------- 2/3 [IPython]
#    -------------------------- ------------- 2/3 [IPython]
#    -------------------------- ------------- 2/3 [IPython]
#    -------------------------- ------------- 2/3 [IPython]
#    -------------------------- ------------- 2/3 [IPython]
#    -------------------------- ------------- 2/3 [IPython]
#    ---------------------------------------- 3/3 [IPython]
#
# Successfully installed IPython-7.34.0 backcall-0.2.0 pickleshare-0.7.5

# %%
import IPython
IPython.__version__
# Out:
# '7.34.0'

# %%
nlp = spacy.load('en_core_web_sm')
from IPython.display import display
doc = nlp('Apple is looking at buying UK startup for $1 billion')
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj False
# is be AUX VBZ aux True
# looking look VERB VBG ROOT False
# at at ADP IN prep True
# buying buy VERB VBG pcomp False
# UK UK PROPN NNP dobj False
# startup startup VERB VBD advcl False
# for for ADP IN prep True
# $ $ SYM $ quantmod False
# 1 1 NUM CD compound False
# billion billion NUM CD pobj False

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# UK 27 29 GPE
# $1 billion 42 52 MONEY

# %% [markdown]
# How about visualizing using spacy functionality

# %%
from spacy import displacy
text = "When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously."
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
displacy.serve(doc, style='ent')
# Out:
# C:\Users\gerry\anaconda3\envs\NLP\Lib\site-packages\spacy\displacy\__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sebastian Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few people outside of the company took him seriously.</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [02/Aug/2025 14:15:28] "GET / HTTP/1.1" 200 1456
# 127.0.0.1 - - [02/Aug/2025 14:15:28] "GET /favicon.ico HTTP/1.1" 200 1456
# Shutting down server on port 5000.

# %%
from IPython.display import display
